# %%
# !wget https://storage.googleapis.com/tf_model_garden/vision/waste_identification_ml/material_model.zip 
# !wget https://storage.googleapis.com/tf_model_garden/vision/waste_identification_ml/material_form_model.zip 
# !wget https://storage.googleapis.com/tf_model_garden/vision/waste_identification_ml/plastic_types_model.zip
# Out:
# --2023-08-11 21:23:55--  https://storage.googleapis.com/tf_model_garden/vision/waste_identification_ml/material_model.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.138.128, 142.250.114.128, 142.250.113.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.138.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 521320844 (497M) [application/zip]
# Saving to: ‘material_model.zip’
#
# material_model.zip  100%[===================>] 497.17M   139MB/s    in 3.8s
#
# 2023-08-11 21:23:59 (131 MB/s) - ‘material_model.zip’ saved [521320844/521320844]
#
# --2023-08-11 21:24:00--  https://storage.googleapis.com/tf_model_garden/vision/waste_identification_ml/material_form_model.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.115.128, 142.250.138.128, 142.251.116.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.115.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 523568744 (499M) [application/zip]
# Saving to: ‘material_form_model.zip’
#
# material_form_model 100%[===================>] 499.31M  85.3MB/s    in 5.8s
#
# 2023-08-11 21:24:07 (86.3 MB/s) - ‘material_form_model.zip’ saved [523568744/523568744]
#
# --2023-08-11 21:24:08--  https://storage.googleapis.com/tf_model_garden/vision/waste_identification_ml/plastic_types_model.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.113.128, 142.251.116.128, 142.250.114.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.113.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 521268394 (497M) [application/zip]
# Saving to: ‘plastic_types_model.zip’
#
# plastic_types_model 100%[===================>] 497.12M   103MB/s    in 5.7s
#
# 2023-08-11 21:24:14 (87.8 MB/s) - ‘plastic_types_model.zip’ saved [521268394/521268394]

# %%
# %%bash
# mkdir material material_form plastic_type
# unzip material_model.zip -d material/
# unzip material_form_model.zip -d material_form/
# unzip plastic_types_model.zip -d plastic_type/
# Out:
# Archive:  material_model.zip
#    creating: material/saved_model/
#   inflating: material/saved_model/params.yaml
#    creating: material/saved_model/saved_model/
#   inflating: material/saved_model/saved_model/saved_model.pb
#    creating: material/saved_model/saved_model/variables/
#   inflating: material/saved_model/saved_model/variables/variables.data-00000-of-00001
#   inflating: material/saved_model/saved_model/variables/variables.index
#    creating: material/saved_model/checkpoint/
#   inflating: material/saved_model/checkpoint/ckpt-1.data-00000-of-00001
#   inflating: material/saved_model/checkpoint/checkpoint
#   inflating: material/saved_model/checkpoint/ckpt-1.index
#    creating: material/tflite_model/
#   inflating: material/tflite_model/model.tflite
# Archive:  material_form_model.zip
#    creating: material_form/saved_model/
#   inflating: material_form/saved_model/params.yaml
#    creating: material_form/saved_model/saved_model/
#   inflating: material_form/saved_model/saved_model/saved_model.pb
#    creating: material_form/saved_model/saved_model/variables/
#   inflating: material_form/saved_model/saved_model/variables/variables.data-00000-of-00001
#   inflating: material_form/saved_model/saved_model/variables/variables.index
#    creating: material_form/saved_model/checkpoint/
#   inflating: material_form/saved_model/checkpoint/ckpt-1.data-00000-of-00001
#   inflating: material_form/saved_model/checkpoint/checkpoint
#   inflating: material_form/saved_model/checkpoint/ckpt-1.index
#    creating: material_form/tflite_model/
#   inflating: material_form/tflite_model/model.tflite
# Archive:  plastic_types_model.zip
#    creating: plastic_type/saved_model/
#   inflating: plastic_type/saved_model/params.yaml
#    creating: plastic_type/saved_model/saved_model/
#   inflating: plastic_type/saved_model/saved_model/saved_model.pb
#    creating: plastic_type/saved_model/saved_model/variables/
#   inflating: plastic_type/saved_model/saved_model/variables/variables.data-00000-of-00001
#   inflating: plastic_type/saved_model/saved_model/variables/variables.index
#    creating: plastic_type/saved_model/checkpoint/
#   inflating: plastic_type/saved_model/checkpoint/ckpt-1.data-00000-of-00001
#   inflating: plastic_type/saved_model/checkpoint/checkpoint
#   inflating: plastic_type/saved_model/checkpoint/ckpt-1.index
#    creating: plastic_type/tflite_model/
#   inflating: plastic_type/tflite_model/model.tflite

# %%
# %%bash
# ls
# pwd
# touch material_labels.pbtxt
# ls
# Out:
# material
# material_form
# material_form_model.zip
# material_model.zip
# plastic_type
# plastic_types_model.zip
# /home/wsuser/work
# material
# material_form
# material_form_model.zip
# material_labels.pbtxt
# material_model.zip
# plastic_type
# plastic_types_model.zip

# %%
# %%bash
# echo '# Mapping of material label ids to string name and human readable string label.
# # Source: U.S. Environmental Protection Agency (http://shortn/_ktDlFMfXm3)
# item {
# id: 1
# name: "inorganic_waste"
# display_name: "Soil, bits of concrete and stones"
# }
# item {
# id: 2
# name: "textiles"
# display_name: "Discarded clothing, carpet, sheets and towels"
# }
# item {
# id: 3
# name: "rubber_and_leather"
# display_name:
#   "Rubber and leather products such as clothing footwear, tires, gaskets and "
#   "furniture"
# }
# item {
# id: 4
# name: "wood"
# display_name:
#   "Wood products such as cabinets, furniture, and packaging like crates and "
#   "pallets"
# }
# item {
# id: 5
# name: "food"
# display_name:
#   "Residential, commercial (supermarkets, food whoesale, restaurants, hotels, "
#   "sports venues) and insitutional (hospitals, offices, universities, schools, "
#   "food banks) food waste"
# }
# item {
# id: 6
# name: "plastics"
# display_name:
#   "Plastic products such as bags, sacks, wraps, cups, bottles, jugs, "
#   "containers, lids, utensils, medical devices and household items"
# }
# item {
# id: 7
# name: "yard_trimmings"
# display_name:
#   "Grass, leaves and tree and brush trimmings from residential, institutional "
#   "and commercial sources"
# }
# item {
# id: 8
# name: "fiber"
# display_name:
#   "Cardboard products such as office papers, newspapers, tissue paper, paper "
#   "plates, cups, corrugated boxes, milk cartons, and bags and sacks"
# }
# item {
# id: 9
# name: "glass"
# display_name:
#   "Glass products such as beer and soft drink bottles, wine and liquor "
#   "bottles, and bottles or jars for food, cosmetics and other products"
# }
# item {
# id: 10
# name: "metals"
# display_name:
#   "Ferrous (iron and steel), non-ferrous (lead, copper and zinc) and aluminum "
#   "products such as containers, packaging, appliances, batteries, electronics "
#   "and furniture"
# }' > material_labels.pbtxt

# %%
# %%bash
# cat material_labels.pbtxt
# mv material_labels.pbtxt material/
# Out:
# cat: material_labels.pbtxt: No such file or directory
# mv: cannot stat 'material_labels.pbtxt': No such file or directory
# bash: line 4: !git: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cat material_labels.pbtxt\nmv material_labels.pbtxt material/\n# Clone the tensorflow models repository\n!git clone --depth 1 https://github.com/tensorflow/models\n')
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File /opt/conda/envs/Python-3.10/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'cat material_labels.pbtxt\nmv material_labels.pbtxt material/\n# Clone the tensorflow models repository\n!git clone --depth 1 https://github.com/tensorflow/models\n'' returned non-zero exit status 127.

# %%
# Clone the tensorflow models repository
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 3934, done.
# remote: Counting objects: 100% (3934/3934), done.
# remote: Compressing objects: 100% (3050/3050), done.
# remote: Total 3934 (delta 1139), reused 1885 (delta 830), pack-reused 0
# Receiving objects: 100% (3934/3934), 49.69 MiB | 27.73 MiB/s, done.
# Resolving deltas: 100% (1139/1139), done.

# %%
# %%bash
# sudo apt install -y protobuf-compiler
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf2/setup.py .
# python -m pip install .
# Out:
# bash: line 1: sudo: command not found
# Processing /home/wsuser/work/models/research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting apache-beam
#   Downloading apache_beam-2.49.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 73.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from object-detection==0.1) (9.3.0)
# Requirement already satisfied: lxml in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from object-detection==0.1) (3.5.2)
# Collecting Cython
#   Downloading Cython-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 87.8 MB/s eta 0:00:00
# Collecting contextlib2
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 kB 68.0 MB/s eta 0:00:00
# Requirement already satisfied: six in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from object-detection==0.1) (1.16.0)
# Collecting pycocotools
#   Downloading pycocotools-2.0.6.tar.gz (24 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from object-detection==0.1) (1.8.1)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from object-detection==0.1) (1.4.3)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.13.1-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 91.8 MB/s eta 0:00:00
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.33.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.6/28.6 MB 50.6 MB/s eta 0:00:00
# Requirement already satisfied: keras in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from object-detection==0.1) (2.9.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 23.5 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 37.8 MB/s eta 0:00:00
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Collecting regex
#   Downloading regex-2023.8.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.9/771.9 kB 77.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.23.1)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting immutabledict
#   Downloading immutabledict-3.0.0-py3-none-any.whl (4.0 kB)
# Collecting gin-config
#   Downloading gin_config-0.5.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 23.5 MB/s eta 0:00:00
# Collecting py-cpuinfo>=3.3.0
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting pyyaml<5.4.0,>=5.1
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 56.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 32.6 MB/s eta 0:00:00
# Collecting tensorflow-datasets
#   Downloading tensorflow_datasets-4.9.2-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 88.5 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.13.0
#   Downloading tensorflow_text-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 91.9 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.1.96)
# Requirement already satisfied: psutil>=5.4.3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.0)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 192.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tensorflow~=2.13.0
#   Downloading tensorflow-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 4.6 MB/s eta 0:00:00
# Collecting google-api-python-client>=1.6.7
#   Downloading google_api_python_client-2.96.0-py2.py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 90.9 MB/s eta 0:00:00
# Collecting kaggle>=1.3.9
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 28.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.8.0.76-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 37.0 MB/s eta 0:00:00
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.5-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from pandas->object-detection==0.1) (2022.1)
# Requirement already satisfied: absl-py>=0.2.2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tf-slim->object-detection==0.1) (1.0.0)
# Collecting objsize<0.7.0,>=0.6.1
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 99.4 MB/s eta 0:00:00
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.22.3-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (1.42.0)
# Collecting fasteners<1.0,>=0.3
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: typing-extensions>=3.7.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (4.3.0)
# Collecting pymongo<5.0.0,>=3.8.0
#   Downloading pymongo-4.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (603 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.6/603.6 kB 74.6 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (8.0.0)
# Collecting crcmod<2.0,>=1.7
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 30.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting protobuf<4.24.0,>=3.20.3
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 59.6 MB/s eta 0:00:00
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 45.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pydot<2,>=1.2.0
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting orjson<4.0
#   Downloading orjson-3.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 38.7 MB/s eta 0:00:00
# Collecting cloudpickle~=2.2.1
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting httplib2<0.23.0,>=0.8
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 32.7 MB/s eta 0:00:00
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 kB 15.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cycler>=0.10.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from lvis->object-detection==0.1) (0.11.0)
# Collecting opencv-python>=4.1.0.25
#   Downloading opencv_python-4.8.0.76-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 29.1 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.1.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from lvis->object-detection==0.1) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib->object-detection==0.1) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib->object-detection==0.1) (4.25.0)
# Collecting tensorflow-io-gcs-filesystem==0.33.0
#   Downloading tensorflow_io_gcs_filesystem-0.33.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 108.1 MB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5
#   Downloading google_api_core-2.11.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.5/120.5 kB 36.2 MB/s eta 0:00:00
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.33.0)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: certifi in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2023.7.22)
# Requirement already satisfied: tqdm in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.0)
# Collecting python-slugify
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.11)
# Collecting bleach
#   Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 35.4 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 60.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.4)
# Collecting keras
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 101.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (65.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Collecting tensorboard<2.14,>=2.13
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 94.5 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Collecting flatbuffers>=23.1.21
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Collecting tensorflow-estimator<2.14,>=2.13.0
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 55.0 MB/s eta 0:00:00
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.6.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 70.5 MB/s eta 0:00:00
# Collecting absl-py>=0.2.2
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 37.9 MB/s eta 0:00:00
# Requirement already satisfied: dm-tree~=0.1.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.5)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: scikit-learn>=0.21.3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.1)
# Collecting etils[enp,epath]>=0.9.0
#   Downloading etils-1.4.1-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 40.9 MB/s eta 0:00:00
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting array-record
#   Downloading array_record-0.4.1-py310-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 90.9 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-metadata in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.8.0)
# Requirement already satisfied: click in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.0.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.38.4)
# Collecting importlib_resources
#   Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: zipp in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Collecting google-auth<3.0.0.dev0,>=1.19.0
#   Downloading google_auth-2.22.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.8/181.8 kB 47.0 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.1)
# Collecting grpcio!=1.48.0,<2,>=1.33.1
#   Downloading grpcio-1.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 98.2 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.3)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 106.4 MB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.4)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 30.8 MB/s eta 0:00:00
# Collecting protobuf<4.24.0,>=3.20.3
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 88.5 MB/s eta 0:00:00
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, pycocotools, crcmod, dill, hdfs, kaggle, pyyaml, seqeval, docopt, promise
#   Building wheel for object-detection (setup.py): started
#   Building wheel for object-detection (setup.py): finished with status 'done'
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1663230 sha256=8d9edb841ba6e909f3f140aaeec20611ced4627d4018fadce6805d4ad5c3b66f
#   Stored in directory: /tmp/wsuser/pip-ephem-wheel-cache-u6ylku7b/wheels/99/b8/9a/f376d23a5e5cf4f8032cdccc14516fe7a4153ddfc46b1f25c3
#   Building wheel for avro-python3 (setup.py): started
#   Building wheel for avro-python3 (setup.py): finished with status 'done'
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44008 sha256=8d160add17cc3bff558a7a5e9fb9b6ccf7ef1a9c958a600deb3c5d26a4675272
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/bc/85/62/6cdd81c56f923946b401cecff38055b94c9b766927f7d8ca82
#   Building wheel for pycocotools (pyproject.toml): started
#   Building wheel for pycocotools (pyproject.toml): finished with status 'done'
#   Created wheel for pycocotools: filename=pycocotools-2.0.6-cp310-cp310-linux_x86_64.whl size=101701 sha256=fc07e6104ec046e41669212ff51c312029ec8dd212cd88790f27f5f91ab53a6a
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/58/e6/f9/f87c8f8be098b51b616871315318329cae12cdb618f4caac93
#   Building wheel for crcmod (setup.py): started
#   Building wheel for crcmod (setup.py): finished with status 'done'
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=23339 sha256=879b1d97b521ed50db01915839c18d25f8159762064309fbfd4b0e72a6b0e363
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78542 sha256=5f09ced50a6d1ab0bf099747e8e20b314896a8070a8135a27d921f52430cfb98
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for hdfs (setup.py): started
#   Building wheel for hdfs (setup.py): finished with status 'done'
#   Created wheel for hdfs: filename=hdfs-2.7.2-py3-none-any.whl size=34182 sha256=a22468704c305a6753456679ceed9e4a31e84787345692a75de2b92d09000b59
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/ab/39/8e/e1905de9af8ae74911cd3e53e721995cd230816f63776e5825
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'done'
#   Created wheel for kaggle: filename=kaggle-1.5.16-py3-none-any.whl size=110703 sha256=7f2026ba6937c2edb859376a775ed2002b7ae7ccafcfdab229b2b81953776ab0
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/43/4b/fb/736478af5e8004810081a06259f9aa2f7c3329fc5d03c2c412
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp310-cp310-linux_x86_64.whl size=44635 sha256=2eacc0917e012d53741bc8f932a5b5e7c61e0923690b74ff75716c0c97495c8b
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/0b/a9/6a/d0a6981a8dbb698845178818642f72ce179f14336908c7df01
#   Building wheel for seqeval (setup.py): started
#   Building wheel for seqeval (setup.py): finished with status 'done'
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16179 sha256=2129062400e242ba7913651d0ed463de11d16cb9da60de1834cc52b2750c2277
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=5930f2a7d6c11c994c6e1c12ef0f20efb796471c74f5442ca4b04b30b2fbe713
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21502 sha256=0e9a0569789fda8149b680b245881ccde88fa32c61ee788c786f18e4dc87b2f0
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/54/4e/28/3ed0e1c8a752867445bab994d2340724928aa3ab059c57c8db
# Successfully built object-detection avro-python3 pycocotools crcmod dill hdfs kaggle pyyaml seqeval docopt promise
# Installing collected packages: webencodings, text-unidecode, py-cpuinfo, libclang, gin-config, flatbuffers, docopt, crcmod, zstandard, uritemplate, toml, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, regex, pyyaml, python-slugify, pyparsing, protobuf, promise, portalocker, orjson, opencv-python-headless, opencv-python, objsize, keras, importlib_resources, immutabledict, grpcio, fasteners, fastavro, etils, dnspython, dill, Cython, contextlib2, colorama, cloudpickle, bleach, avro-python3, absl-py, tf-slim, tensorflow-model-optimization, tensorflow_io, sacrebleu, pymongo, pydot, proto-plus, kaggle, httplib2, hdfs, google-auth, seqeval, oauth2client, google-auth-oauthlib, google-auth-httplib2, google-api-core, apache-beam, tensorboard, pycocotools, lvis, google-api-python-client, array-record, tensorflow-datasets, tensorflow, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow-io-gcs-filesystem
#     Found existing installation: tensorflow-io-gcs-filesystem 0.26.0
#     Uninstalling tensorflow-io-gcs-filesystem-0.26.0:
#       Successfully uninstalled tensorflow-io-gcs-filesystem-0.26.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.1.0
#     Uninstalling cloudpickle-2.1.0:
#       Successfully uninstalled cloudpickle-2.1.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.0.0
#     Uninstalling absl-py-1.0.0:
#       Successfully uninstalled absl-py-1.0.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.33.0
#     Uninstalling google-auth-1.33.0:
#       Successfully uninstalled google-auth-1.33.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.4
#     Uninstalling google-auth-oauthlib-0.4.4:
#       Successfully uninstalled google-auth-oauthlib-0.4.4
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.3
#     Uninstalling tensorflow-2.9.3:
#       Successfully uninstalled tensorflow-2.9.3
#   Attempting uninstall: tensorflow-text
#     Found existing installation: tensorflow-text 2.9.0
#     Uninstalling tensorflow-text-2.9.0:
#       Successfully uninstalled tensorflow-text-2.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 1.6.5 requires protobuf<=3.20.1, but you have protobuf 3.20.3 which is incompatible.
# pytorch-lightning 1.6.5 requires PyYAML>=5.4, but you have pyyaml 5.3.1 which is incompatible.
# onnx 1.12.0 requires protobuf<=3.20.1,>=3.12.2, but you have protobuf 3.20.3 which is incompatible.
# autoai-ts-libs 2.0.13 requires tensorflow<2.13,>=2.7.0; python_version >= "3.9", but you have tensorflow 2.13.0 which is incompatible.
# Successfully installed Cython-3.0.0 absl-py-1.4.0 apache-beam-2.49.0 array-record-0.4.1 avro-python3-1.10.2 bleach-6.0.0 cloudpickle-2.2.1 colorama-0.4.6 contextlib2-21.6.0 crcmod-1.7 dill-0.3.1.1 dnspython-2.4.2 docopt-0.6.2 etils-1.4.1 fastavro-1.8.2 fasteners-0.18 flatbuffers-23.5.26 gin-config-0.5.0 google-api-core-2.11.1 google-api-python-client-2.96.0 google-auth-2.22.0 google-auth-httplib2-0.1.0 google-auth-oauthlib-1.0.0 grpcio-1.57.0 hdfs-2.7.2 httplib2-0.22.0 immutabledict-3.0.0 importlib_resources-6.0.1 kaggle-1.5.16 keras-2.13.1 libclang-16.0.6 lvis-0.5.3 oauth2client-4.1.3 object-detection-0.1 objsize-0.6.1 opencv-python-4.8.0.76 opencv-python-headless-4.8.0.76 orjson-3.9.4 portalocker-2.7.0 promise-2.3 proto-plus-1.22.3 protobuf-3.20.3 py-cpuinfo-9.0.0 pycocotools-2.0.6 pydot-1.4.2 pymongo-4.4.1 pyparsing-2.4.7 python-slugify-8.0.1 pyyaml-5.3.1 regex-2023.8.8 sacrebleu-2.2.0 seqeval-1.2.2 tensorboard-2.13.0 tensorboard-data-server-0.7.1 tensorflow-2.13.0 tensorflow-datasets-4.9.2 tensorflow-estimator-2.13.0 tensorflow-io-gcs-filesystem-0.33.0 tensorflow-model-optimization-0.7.5 tensorflow-text-2.13.0 tensorflow_io-0.33.0 text-unidecode-1.3 tf-models-official-2.13.1 tf-slim-1.1.0 toml-0.10.2 uritemplate-4.1.1 webencodings-0.5.1 zstandard-0.21.0

# %%
# %%bash
# pip install ibmcloudant
# pip install ibm-cloud-sdk-core
# pip install opencv-python-headless
# pip install pymongo
# pip install Pillow
# pip install paho-mqtt
# pip install matplotlib
# pip install numpy
# pip install tensorflow
# pip install tensorflow_hub
# pip install pyvirtualdisplay
# Out:
# Requirement already satisfied: ibmcloudant in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (0.4.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.5.3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibmcloudant) (2.8.2)
# Requirement already satisfied: ibm-cloud-sdk-core==3.16.7 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibmcloudant) (3.16.7)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibmcloudant) (2.4.0)
# Requirement already satisfied: requests<3.0,>=2.20 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibmcloudant) (2.31.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibm-cloud-sdk-core==3.16.7->ibmcloudant) (1.26.11)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.5.3->ibmcloudant) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3.0,>=2.20->ibmcloudant) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3.0,>=2.20->ibmcloudant) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3.0,>=2.20->ibmcloudant) (2023.7.22)
# Requirement already satisfied: ibm-cloud-sdk-core in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (3.16.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.5.3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibm-cloud-sdk-core) (2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibm-cloud-sdk-core) (2.31.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibm-cloud-sdk-core) (2.4.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ibm-cloud-sdk-core) (1.26.11)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.5.3->ibm-cloud-sdk-core) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->ibm-cloud-sdk-core) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->ibm-cloud-sdk-core) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->ibm-cloud-sdk-core) (3.3)
# Requirement already satisfied: opencv-python-headless in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.19.3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from opencv-python-headless) (1.23.1)
# Requirement already satisfied: pymongo in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (4.4.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from pymongo) (2.4.2)
# Requirement already satisfied: Pillow in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (9.3.0)
# Requirement already satisfied: paho-mqtt in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: matplotlib in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (3.5.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (1.23.1)
# Requirement already satisfied: tensorflow in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: setuptools in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (0.33.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.23.1)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.57.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.22.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from packaging->tensorflow) (2.4.7)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (1.26.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)
# Requirement already satisfied: tensorflow_hub in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow_hub) (3.20.3)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from tensorflow_hub) (1.23.1)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
# export PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python
# Import necessary libraries
from ibmcloudant.cloudant_v1 import CloudantV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
import cv2
import pymongo
import datetime
from PIL import ImageFont, ImageDraw, Image
from pymongo import MongoClient
import paho.mqtt.client as mqtt
import urllib.parse
from pymongo import MongoClient
import json
import cv2
import matplotlib.pyplot as plt
import numpy as np
from six import BytesIO
from PIL import Image
import tensorflow as tf
import tensorflow_hub as hub
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import ops as utils_ops
import ssl
from urllib.request import urlopen
import uuid
import socket

# Set MQTT broker information (using Mosquitto broker)
mqtt_broker = "localhost"  # Replace with the address of your Mosquitto broker
mqtt_port = 1883  # Default MQTT port
mqtt_topic = "waste_detection"  # Replace with the desired MQTT topic

# Create an MQTT client instance
mqtt_client = mqtt.Client()

# Connect to the MQTT broker
mqtt_client.connect(mqtt_broker, mqtt_port)

def get_mac_address():
    try:
        mac_address = uuid.UUID(int=uuid.getnode()).hex[-12:]
    except Exception as e:
        print("Error getting MAC address:", e)
        return None

    return ":".join([mac_address[i:i+2] for i in range(0, 12, 2)])


# Update the Cloudant credentials
credentials = {
    "apikey": "tmSRIS_CQp3vRDKNqaRgMjaGTMV9MNkYvmKlhejpMKxG",
    "url": "https://d66297a5-6c29-485c-840e-5903af9a45f7-bluemix.cloudantnosqldb.appdomain.cloud",
    "username": "apikey-v2-tuy7g6x55ttl869okke0el42d5ljflybly5txrxy3is"
}

# Create an IAM Authenticator
authenticator = IAMAuthenticator(credentials['apikey'])

# Create a Cloudant client
client = CloudantV1(authenticator=authenticator)
client.set_service_url(credentials['url'])

# Specify the database name
database_name = "test"  # Replace 'your_database_name' with the desired database name

# Get the existing databases to check if the specified database exists
response = client.get_all_dbs().get_result()
if database_name not in response:
    # If the specified database doesn't exist, create it
    response = client.put_database(db=database_name).get_result()

# # Escape username and password
# username = urllib.parse.quote_plus('av34')
# password = urllib.parse.quote_plus('test12345')

# # Construct the MongoDB URI with escaped username and password
# uri = f"mongodb+srv://{username}:{password}@cluster0.w52bjm1.mongodb.net/"

# # Establish a connection to MongoDB
# client = MongoClient(uri)

# # Create or access the database
# db = client['SegBin']  # Replace 'my_database' with the desired database name

# # Create or access the collection
# collection = db['test']  # Replace 'my_collection' with the desired collection name

# Rest of the code...


def capture_image():
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Failed to open webcam")
        return
    ret, frame = cap.read()
    if not ret:
        print("Failed to capture image")
        return
    cv2.imshow("Captured Image", frame)
    cv2.imwrite("Science_plastic.jpg", frame)
    cap.release()
    cv2.destroyAllWindows()


ALL_MODELS = {
'material_model' : 'material/saved_model/saved_model'
# 'material_form_model' : '/Users/aadityavoruganti/SegBin.ai/Image-classfication/Image-classfication Backend/material_form/saved_model/saved_model/',
# 'plastic_model' : '/Users/aadityavoruganti/SegBin.ai/Image-classfication/Image-classfication Backend/plastic_type/saved_model/saved_model/'
}

def normalize_image(image,
                    offset=(0.485, 0.456, 0.406),
                    scale=(0.229, 0.224, 0.225)):
  with tf.name_scope('normalize_image'):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    offset = tf.constant(offset)
    offset = tf.expand_dims(offset, axis=0)
    offset = tf.expand_dims(offset, axis=0)
    image -= offset

    scale = tf.constant(scale)
    scale = tf.expand_dims(scale, axis=0)
    scale = tf.expand_dims(scale, axis=0)
    image /= scale
    return image


def load_image_into_numpy_array(path, target_size=(1024, 512)):
    image = None
    if path.startswith('http'):
        response = urlopen(path)
        image_data = response.read()
        image_data = BytesIO(image_data)
        image = Image.open(image_data)
    else:
        image_data = tf.io.gfile.GFile(path, 'rb').read()
        image = Image.open(BytesIO(image_data))
    image = image.resize(target_size)
    if image.mode == 'RGBA':
        image = image.convert('RGB')
    image_np = np.array(image)
    image_np_expanded = np.expand_dims(image_np, axis=0)

    return image_np_expanded.astype(np.uint8)

def build_inputs_for_segmentation(image):
    image = normalize_image(image)
    return image

model_display_name = 'material_model' # @param ['material_model','material_form_model','plastic_model']
model_handle = ALL_MODELS[model_display_name]

print('Selected model:'+ model_display_name)
print('Model Handle at TensorFlow Hub: {}'.format(model_handle))

if model_display_name == 'material_model':
  PATH_TO_LABELS = 'material/material_labels.pbtxt'
# elif model_display_name == 'material_form_model':
#   PATH_TO_LABELS = '/Users/aadityavoruganti/SegBin.ai/Image-classfication/Image-classfication Backend/models/official/projects/waste_identification_ml/pre_processing/config/data/material_form_labels.pbtxt'
# elif model_display_name == 'plastic_model':
#   PATH_TO_LABELS = '/Users/aadityavoruganti/SegBin.ai/Image-classfication/Image-classfication Backend/models/official/projects/waste_identification_ml/pre_processing/config/data/plastic_type_labels.pbtxt'

print('Labels selected for',model_display_name)
print('\n')
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)
category_index

# Define the condensed labels mapping
condensed_labels = {
    1: 'Soil, bits of concrete and stones',
    2: 'Discarded clothing, carpet, sheets and towels',
    3: 'Rubber and leather products such as clothing footwear, tires, gaskets and furniture',
    4: 'Wood products such as cabinets, furniture, and packaging like crates and pallets',
    5: 'Residential, commercial (supermarkets, food wholesale, restaurants, hotels, sports venues) and institutional (hospitals, offices, universities, schools, food banks) food waste',
    6: 'Plastic products such as bags, sacks, wraps, cups, bottles, jugs, containers, lids, utensils, medical devices and household items',
    7: 'Grass, leaves and tree and brush trimmings from residential, institutional and commercial sources',
    8: 'Cardboard products such as office papers, newspapers, tissue paper, paper plates, cups, corrugated boxes, milk cartons, and bags and sacks',
    9: 'Glass products such as beer and soft drink bottles, wine and liquor bottles, and bottles or jars for food, cosmetics and other products',
    10: 'Ferrous (iron and steel), non-ferrous (lead, copper and zinc) and aluminum products such as containers, packaging, appliances, batteries, electronics and furniture'
}


print('loading model...')
hub_model = hub.load(model_handle)
print('model loaded!')

while True:

    if __name__ == '__main__':
        cap = cv2.VideoCapture(0)
        if not cap.isOpened():
            print("Failed to open webcam")
            exit()
        while True:
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture image")
                break
            cv2.imshow("Webcam", frame)
            if cv2.waitKey(1) & 0xFF == ord('c'):
                cv2.imwrite("Science_plastic.jpg", frame)
                print("Image captured!")
                break
        cap.release()
        cv2.destroyAllWindows()

    IMAGES_FOR_TEST = {
    'TestImage' : 'Science_plastic.jpg'
    } 

    selected_image = "TestImage" #@param ["Image1", "TestImage"]
    flip_image_horizontally = False #@param {type:"boolean"}
    convert_image_to_grayscale = False #@param {type:"boolean"}

    image_path = IMAGES_FOR_TEST[selected_image]
    image_np = load_image_into_numpy_array(image_path)

    if(flip_image_horizontally):
        image_np[0] = np.fliplr(image_np[0]).copy()

    if(convert_image_to_grayscale):
        image_np[0] = np.tile(
        np.mean(image_np[0], 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

    print('min:',np.min(image_np[0]), 'max:', np.max(image_np[0]))
    plt.figure(figsize=(24,32))
    plt.imshow(image_np[0])
    # plt.savefig('figurepreprocess.png') 
    # plt.show()
    plt.close()  # Close the figure

    hub_model_fn = hub_model.signatures["serving_default"]
    height=hub_model_fn.structured_input_signature[1]['inputs'].shape[1]
    width = hub_model_fn.structured_input_signature[1]['inputs'].shape[2]
    input_size = (height, width)
    print(input_size)

    image_np_cp = cv2.resize(image_np[0], input_size[::-1], interpolation = cv2.INTER_AREA)
    image_np = build_inputs_for_segmentation(image_np_cp)
    image_np = tf.expand_dims(image_np, axis=0)
    image_np.get_shape()

    plt.figure(figsize=(24,32))
    plt.imshow(image_np[0])
    # plt.savefig('figureprocessed.png')
    # plt.show()
    plt.close()  # Close the figure

    results = hub_model_fn(image_np)
    result = {key:value.numpy() for key,value in results.items()}
    print(result.keys())

    label_id_offset = 0
    min_score_thresh =0.6
    use_normalized_coordinates=True

    if use_normalized_coordinates:
        result['detection_boxes'][0][:,[0,2]] /= height
        result['detection_boxes'][0][:,[1,3]] /= width

    if 'detection_masks' in result:
        detection_masks = tf.convert_to_tensor(result['detection_masks'][0])
        detection_boxes = tf.convert_to_tensor(result['detection_boxes'][0])
        detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes,
                    image_np.shape[1], image_np.shape[2])
        detection_masks_reframed = tf.cast(detection_masks_reframed > 0.5,
                                            np.uint8)
        result['detection_masks_reframed'] = detection_masks_reframed.numpy()



    mask_count = np.sum(result['detection_scores'][0] >= min_score_thresh)
    print('Total number of objects found are:', mask_count)
    mask = np.zeros_like(detection_masks_reframed[0])
    for i in range(mask_count):
        if result['detection_scores'][0][i] >= min_score_thresh:
            mask += detection_masks_reframed[i]

    mask = tf.clip_by_value(mask, 0,1)
    plt.figure(figsize=(24,32))
    plt.imshow(mask,cmap='gray')
    # plt.savefig('figuremask.png')
    # plt.show()
    plt.close()  # Close the figure

    detected_labels = []
    for i in range(mask_count):
        if result['detection_scores'][0][i] >= min_score_thresh:
            label = category_index[result['detection_classes'][0][i] + label_id_offset]['name']
            detected_labels.append(label)

    detection_scores = result['detection_scores'][0]
    detected_scores = detection_scores[:mask_count]

    total_score = np.sum(detected_scores)
    accuracy_percentages = [score / total_score * 100 for score in detected_scores]

    for label, accuracy in zip(detected_labels, accuracy_percentages):
        print(f"Detected object: {label}, Accuracy: {accuracy:.2f}%")

    # Get the current date and time
    current_datetime = datetime.datetime.now()

    if __name__ == "__main__":
        mac_address = get_mac_address()

    # ... Previous code ...

    # Convert datetime to string representation
    current_datetime_str = current_datetime.isoformat()

    # Create a dictionary for the JSON packet
    json_packet = {
        'mac_address': mac_address,
        'timestamp': current_datetime_str,
        'detected_objects': []
    }

    # Define the labels for each waste category
    Category1_Labels = [
        'Soil, bits of concrete and stones',
        'Grass, leaves and tree and brush trimmings',
        'Residential, commercial and institutional food waste'
    ]

    Category2_Labels = [
        'Cardboard products such as office papers, newspapers, tissue paper, paper plates, cups, corrugated boxes, milk cartons, and bags and sacks'
        # Add more labels for Category 2 as needed
    ]

    Category3_Labels = [
        'Plastic products such as bags, sacks, wraps, cups, bottles, jugs, containers, lids, utensils, medical devices and household items',
        'Rubber and leather products such as clothing footwear, tires, gaskets and furniture'
        # Add more labels for Category 3 as needed
    ]

    Category4_Labels = [
        'Wood products such as cabinets, furniture, and packaging like crates and pallets',
        'Discarded clothing, carpet, sheets and towels',
        'Glass products such as beer and soft drink bottles, wine and liquor bottles, and bottles or jars for food, cosmetics and other products',
        'Ferrous (iron and steel), non-ferrous (lead, copper and zinc) and aluminum products such as containers, packaging, appliances, batteries, electronics and furniture'
        # Add more labels for Category 4 as needed
    ]

    # Inside the for loop for detected labels and accuracy
    for i in range(mask_count):
        if result['detection_scores'][0][i] >= min_score_thresh:
            label_id = result['detection_classes'][0][i] + label_id_offset
            accuracy = accuracy_percentages[i]

            # Get the corresponding condensed label or use 'Unknown' if not found
            condensed_label = condensed_labels.get(label_id, 'Unknown')
            print(f"Detected object: {condensed_label}, Accuracy: {accuracy:.2f}%")

            # Determine the waste category based on the detected label
            waste_category = None
            if condensed_label in Category1_Labels:
                waste_category = 'Category 1: Organic and Biodegradable Waste'
            elif condensed_label in Category2_Labels:
                waste_category = 'Category 2: Paper and Cardboard Waste'
            elif condensed_label in Category3_Labels:
                waste_category = 'Category 3: Plastics and Rubber Waste'
            elif condensed_label in Category4_Labels:
                waste_category = 'Category 4: Metal and Glass Waste'

            if waste_category:
                print(f"Waste Category: {waste_category}")

            # Create a dictionary for the detected object
            detected_object = {
                'label': condensed_label,
                'accuracy': accuracy,
                'waste_category': waste_category
            }

            # Append the detected object to the JSON packet
            json_packet['detected_objects'].append(detected_object)

    # ... Rest of the code ...



    # # Insert the JSON packet into the collection
    # collection.insert_one(json_packet)

    # Push the JSON packet to the database
    response = client.post_document(db=database_name, document=json_packet).get_result()

    # Publish the JSON packet to the MQTT topic
    mqtt_payload = json.dumps(json_packet)  # Convert the JSON packet to a string
    mqtt_client.publish(mqtt_topic, mqtt_payload)

    # Print the response to verify if the document was successfully inserted
    print(response)
# Out:
# 2023-08-11 17:55:31.814707: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Selected model:material_model
# Model Handle at TensorFlow Hub: material/saved_model/saved_model
# Labels selected for material_model
#
#
# loading model...
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92799) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92619) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88729) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90229) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87879) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88619) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86709) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90519) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89619) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91229) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92449) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85709) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87409) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92879) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86869) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84619) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85799) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87229) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84709) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84879) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88879) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86619) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91729) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90409) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85869) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89229) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84869) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89709) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91869) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92409) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90709) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85729) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91879) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88429) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_86389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_93029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_88529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_85789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90869) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_90039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91449) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_91499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_87859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_89259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_84649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_92529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# model loaded!
# Image captured!
# min: 0 max: 255
# (512, 1024)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# dict_keys(['detection_classes', 'image_info', 'detection_masks', 'num_detections', 'detection_boxes', 'detection_scores'])
# Total number of objects found are: 0
# {'ok': True, 'id': '1321a20aab5742e7fc740089733f34f4', 'rev': '1-346d133b5e15120eb5bf040dc3af86e3'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 197
#     195     exit()
#     196 while True:
# --> 197     ret, frame = cap.read()
#     198     if not ret:
#     199         print("Failed to capture image")
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
